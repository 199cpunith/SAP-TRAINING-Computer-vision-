# %%
import cv2
import numpy as np

# %%
image = cv2.imread("/content/download-compresskaru.com - 2024-04-17T163055.715.png")

# %%
from IPython import get_ipython
from IPython.display import display
import cv2
import numpy as np
from google.colab.patches import cv2_imshow # Import cv2_imshow for Colab compatibility

image = cv2.imread("/content/download-compresskaru.com - 2024-04-17T163055.715.png")

cv2_imshow(image) # Use cv2_imshow instead of cv2.imshow
# cv2.waitKey(0)  # These functions are not needed with cv2_imshow
# cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow # Import cv2_imshow for Colab compatibility

# ... (rest of your code) ...

# Display the original image and the processed image
cv2_imshow(image) # Use cv2_imshow instead of cv2.imshow
cv2_imshow(identity) # Use cv2_imshow instead of cv2.imshow


# Remove or comment out the following lines as they are not needed with cv2_imshow:
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# ... (rest of your code) ...
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
# Apply blurring kernel
kernel2 = np.ones((5, 5), np.float32) / 25
img = cv2.filter2D(src=image, ddepth=-1, kernel=kernel2)

# Use cv2_imshow from google.colab.patches instead of cv2.imshow
from google.colab.patches import cv2_imshow

cv2_imshow(image)  # Display original image
cv2_imshow(img)  # Display blurred image

cv2.waitKey()
cv2.imwrite('blur_kernel.jpg', img)
cv2.destroyAllWindows() # This line might still cause issues. If it does, consider removing it.
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
b,g,r=cv2.split(image)

# %%
g=b//2

# %%
g
# Out:
# array([[127, 127, 124, ..., 123, 122, 123],
#        [127, 126, 126, ..., 125, 122, 125],
#        [127, 125, 125, ..., 121, 121, 124],
#        ...,
#        [107, 115, 118, ..., 127, 127, 127],
#        [110, 107, 119, ..., 126, 127, 127],
#        [115,  93, 115, ..., 127, 127, 127]], dtype=uint8)

# %%
img=cv2.merge((b,g,r))

# %%
from google.colab.patches import cv2_imshow
import cv2

# ... other code ...

# Replace cv2.imshow with cv2_imshow:
cv2_imshow(img)

# cv2.waitKey() and cv2.destroyAllWindows() are typically not needed with cv2_imshow
# but if you're using them for other purposes, they might still need to be replaced
# with Colab-compatible alternatives.
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>
